# %%
import pandas as pd
import ast

# %%
with open("gemini_papers_2.csv", "r", encoding="utf-8") as f:
    rows = [ast.literal_eval(line.strip()) for line in f if line.strip()]

df = pd.DataFrame(rows, columns=["file", "title", 
                                 "What is the main topic and objective of the study?", 
                                 "What knowledge gap does it address?", 
                                 "What knowledge gap does it NOT address or leave open?", 
                                 "Could this paper contribute useful information to my study?"])

# %%
df
# Out:
#                                  file  \
# 0          bitencourt2010relating.pdf
# 1   bretherton1992intercomparison.pdf
# 2         chen2025characteristics.pdf
# 3                  clark2005sting.pdf
# 4          coutodesouza2024thesis.pdf
# ..                                ...
# 72            miranda2026patterns.pdf
# 73               hersbach2020era5.pdf
# 74                 oertel2021warm.pdf
# 75                 gan1991surface.pdf
# 76               gan1994influence.pdf
#
#                                                 title  \
# 0   Relating winds along the Southern Brazilian co...
# 1   An Intercomparison of Methods for Finding Coup...
# 2   Characteristics of Precipitation and Wind Extr...
# 3   The sting at the end of the tail: Model diagno...
# 4   Cyclones in the Southwestern Atlantic: Life Cy...
# ..                                                ...
# 72  Meteoceanographic Patterns Associated with Sev...
# 73                         The ERA5 global reanalysis
# ...
