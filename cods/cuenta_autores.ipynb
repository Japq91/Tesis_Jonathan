# %%
from aux_conta import *
from glob import glob as gb

# %%
# archivos_tex = encontrar_archivos_tex(ruta)
file='../tex_es/05.vf5_result02_tp.tex'
palabra = r"\cite"              # Palabra clave a buscar        
cuenta(palabra,file)
# Out:
# 🔍 Buscando: "\cite"
# 📄 Archivos .tex encontrados: 1
# 🔤 Case sensitive: No
# --------------------------------------------------
#   ⚠️  Error leyendo ../tex_es/05.vf5_result02_tp.tex: [Errno 2] No such file or directory: '../tex_es/05.vf5_result02_tp.tex'
# --------------------------------------------------
# 📊 TOTAL: 0 ocurrencias de "\cite"
#    (1 archivos sin coincidencias)

# %%
# === USO ===
file = '../tex_es/05.vf5_result02_tp.tex'
extraer_citas(file)
# Out:
# ⚠️  Error leyendo ../tex_es/05.vf5_result02_tp.tex: [Errno 2] No such file or directory: '../tex_es/05.vf5_result02_tp.tex'

# %%
# === USO ===
comparar_citas(
    '../tex_es/01.vf7_introducao.tex',      # versión anterior
    '../tex_es/01.vr5_introducao.tex'    # versión nueva
)
# Out:
# 📄 Viejo: 01.vf7_introducao.tex
# 📄 Nuevo: 01.vr5_introducao.tex
# --------------------------------------------------
# ➖ AUTORES ELIMINADOS (7):
#      blanchard2021warm
#      gozzo2014subtropical
#      gramcianinov2024early
#      hannachi2007empirical
#      oertel2021warm
#      sinclair1997objective
#      zscheischler2018future
#
# ➕ AUTORES AGREGADOS (9):
#      bitencourt2010relating
#      dalanhese2023new
#      gan1991surface
#      jones1993climatology
#      kaylee2025convection
#      kodama2019perspective
#      padilhareinke2024objective
#      simmonds1999southern
#      sun2022evaluation

# %%
# === USO ===
comparar_citas_con_cantidad(
    '../tex_es/01.vf7_introducao.tex',      # versión anterior
    '../tex_es/01.vr5_introducao.tex'    # versión nueva
)
# Out:
# 📄 Viejo: 01.vf7_introducao.tex
# 📄 Nuevo: 01.vr5_introducao.tex
# --------------------------------------------------
#   ➕ bitencourt2010relating: 0 → 1  (nuevo)
#   ➖ blanchard2021warm: 1 → 0  (eliminado)
#   ✏️  coutodesouza2024new: 4 → 2  (-2)
#   ✏️  crespo2020potential: 2 → 1  (-1)
#   ➕ dalanhese2023new: 0 → 1  (nuevo)
#   ➕ gan1991surface: 0 → 1  (nuevo)
#   ➖ gozzo2014subtropical: 1 → 0  (eliminado)
#   ➖ gramcianinov2024early: 1 → 0  (eliminado)
#   ➖ hannachi2007empirical: 1 → 0  (eliminado)
#   ➕ jones1993climatology: 0 → 1  (nuevo)
#   ➕ kaylee2025convection: 0 → 1  (nuevo)
#   ➕ kodama2019perspective: 0 → 1  (nuevo)
#   ➖ oertel2021warm: 1 → 0  (eliminado)
#   ➕ padilhareinke2024objective: 0 → 1  (nuevo)
#   ✏️  priestley2022improved: 2 → 1  (-1)
#   ✏️  reboita2010south: 2 → 1  (-1)
#   ✏️  reboita2022from: 3 → 2  (-1)
#   ✏️  reboita2026meteorology: 2 → 4  (+2)
#   ➕ simmonds1999southern: 0 → 1  (nuevo)
#   ✏️  sinclair1994objective: 2 → 1  (-1)
#   ➖ sinclair1997objective: 1 → 0  (eliminado)
#   ➕ sun2022evaluation: 0 → 1  (nuevo)
#   ➖ zscheischler2018future: 1 → 0  (eliminado)
# --------------------------------------------------
# 📊 Total citas viejo: 56
# 📊 Total citas nuevo: 53

# %%
archivos = gb('../tex_es/*vr*.tex')
buscar_autor_en_archivos(sorted(archivos), 'sinclair2023relationship')
# Out:
# 🔍 Buscando: "sinclair2023relationship"
# 📂 Archivos analizados: 10
# 🔤 Case sensitive: No
# ------------------------------------------------------------
# ✅ Encontrado en 3 archivo(s)
#
#   📄 05.vr2_result02_tp.tex
#      → Línea 19: \citet{sinclair2023relationship}
#      → Línea 25: \citep{sinclair2023relationship}
#      📊 Total: 2
#   📄 01.vr5_introducao.tex
#      → Línea 34: \citet{sinclair2023relationship}
#      📊 Total: 1
#   📄 04.vr2_result01_w10.tex
#      → Línea 260: \citep{sinclair2023relationship}
#      📊 Total: 1
# ------------------------------------------------------------
# 📊 TOTAL: 4 ocurrencias en 3 archivo(s)
# {'01.vr5_introducao.tex': {'count': 1,
#   'ocurrencias': [{'linea': 34,
#     'cita_completa': '\\citet{sinclair2023relationship}'}]},
#  '04.vr2_result01_w10.tex': {'count': 1,
#   'ocurrencias': [{'linea': 260,
#     'cita_completa': '\\citep{sinclair2023relationship}'}]},
#  '05.vr2_result02_tp.tex': {'count': 2,
#   'ocurrencias': [{'linea': 19,
#     'cita_completa': '\\citet{sinclair2023relationship}'},
#    {'linea': 25, 'cita_completa': '\\citep{sinclair2023relationship}'}]}}

# %%
import pandas as pd
from buscar_keywords import search_keywords_in_bib
# Una palabra
lista=['precipit',"compos", "lagran", "EOF"][2:]
df = search_keywords_in_bib(
    "../tex_es/bibliografia_vr1.bib", 
    lista,
    
)

# %%
df.sort_values(lista[:], ascending=False)
# Out:
#                              autor  lagran  EOF
# 15                 cardoso2020wind       1    0
# 39               blanchard2021warm       1    0
# 46             cardoso2022synoptic       1    0
# 93                  oertel2021warm       1    0
# 102           gozzo2017climatology       1    0
# 104             coll2024lagrangian       1    0
# 14               sun2022evaluation       0   14
# 94           hannachi2007empirical       0    8
# 98         sasaki2021intraseasonal       0    6
# 29                 rieger2024xeofs       0    3
# 92   bretherton1992intercomparison       0    3
# 86           liang2018multivariate       0    2
# 80                    vera2002cold       0    1
# 99                 hannachi2023eof       0    1
# 103            miranda2026patterns       0    1

# %%
df[df['EOF'] > 0].sort_values('EOF', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EOF'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[df['EOF'] > 0].sort_values('EOF', ascending=False)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'EOF'
